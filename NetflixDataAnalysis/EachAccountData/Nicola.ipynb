# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
netflix_data = pd.read_csv('datasets/netflix-report/CONTENT_INTERACTION/ViewingActivity.csv', encoding='ISO-8859-1', index_col=0)

# %%
netflix_nicola = netflix_data.drop(['Marcus',
                                  'Emily',
                                  'Ð¤Ð¹Ð¶',
                                  'Coco',])
netflix_nicola
# Out:
#                        Start Time  Duration  \
# Profile Name
# Nicola        2023-06-30 18:08:48  00:00:05
# Nicola        2023-06-30 16:54:48  01:12:05
# Nicola        2023-06-28 19:06:48  00:30:32
# Nicola        2023-06-27 16:54:47  00:27:07
# Nicola        2023-06-27 16:53:12  00:00:33
# ...                           ...       ...
# Nicola        2018-02-20 16:19:35  00:01:13
# Nicola        2017-12-07 21:04:34  00:43:06
# Nicola        2017-12-07 20:25:59  00:29:26
# Nicola        2017-12-07 18:10:25  00:24:13
# Nicola        2017-12-07 18:09:48  00:00:07
#
#                                                Attributes  \
# Profile Name
# Nicola                    Autoplayed: user action: None;
# Nicola                                                NaN
# Nicola                                                NaN
# Nicola        Autoplayed: user action: User_Interaction;
# Nicola                                                NaN
# ...

# %%
netflix_nicola = netflix_nicola.drop(['Attributes',
                                  'Supplemental Video Type',
                                  'Bookmark',
                                  'Latest Bookmark'], axis=1)

# %%
netflix_nicola
# Out:
#                        Start Time  Duration  \
# Profile Name
# Nicola        2023-06-30 18:08:48  00:00:05
# Nicola        2023-06-30 16:54:48  01:12:05
# Nicola        2023-06-28 19:06:48  00:30:32
# Nicola        2023-06-27 16:54:47  00:27:07
# Nicola        2023-06-27 16:53:12  00:00:33
# ...                           ...       ...
# Nicola        2018-02-20 16:19:35  00:01:13
# Nicola        2017-12-07 21:04:34  00:43:06
# Nicola        2017-12-07 20:25:59  00:29:26
# Nicola        2017-12-07 18:10:25  00:24:13
# Nicola        2017-12-07 18:09:48  00:00:07
#
#                                                           Title  \
# Profile Name
# Nicola        Black Mirror: Season 6: Joan Is Awful (Episode 1)
# Nicola             Black Mirror: Season 6: Demon 79 (Episode 5)
# Nicola        Black Mirror: Season 6: Beyond the Sea (Episod...
# Nicola        Black Mirror: Season 6: Beyond the Sea (Episod...
# Nicola        Black Mirror: Season 6: Beyond the Sea (Episod...
# ...

# %%
netflix_nicola['Title'].unique()
# Out:
# array(['Black Mirror: Season 6: Joan Is Awful (Episode 1)',
#        'Black Mirror: Season 6: Demon 79 (Episode 5)',
#        'Black Mirror: Season 6: Beyond the Sea (Episode 3)',
#        'Black Mirror: Season 6: Mazey Day (Episode 4)',
#        'Black Mirror: Season 6: Loch Henry (Episode 2)',
#        'Firefly Lane: Season 2: This Must Be the Place (Episode 16)',
#        'Firefly Lane: Season 2: Moondance (Episode 15)',
#        'Firefly Lane: Season 2: I Canâ\x80\x99t Go On, Iâ\x80\x99ll Go On (Episode 14)',
#        "Firefly Lane: Season 2: Can't Fight This Feeling (Episode 13)",
#        'Firefly Lane: Season 2: Time After Time (Episode 12)',
#        'Firefly Lane: Season 2: The Breast Is Yet to Come (Episode 11)',
#        'Firefly Lane: Season 2: All the Worldâ\x80\x99s a Stage (Episode 10)',
#        'Firefly Lane: Season 2: Hart Shaped Box (Episode 9)',
#        'Firefly Lane: Season 2: All Apologies (Episode 8)',
# ...

# %%
netflix_nicola['Title'].unique()
# Out:
# array(['Black Mirror: Season 6: Joan Is Awful (Episode 1)',
#        'Black Mirror: Season 6: Demon 79 (Episode 5)',
#        'Black Mirror: Season 6: Beyond the Sea (Episode 3)',
#        'Black Mirror: Season 6: Mazey Day (Episode 4)',
#        'Black Mirror: Season 6: Loch Henry (Episode 2)',
#        'Firefly Lane: Season 2: This Must Be the Place (Episode 16)',
#        'Firefly Lane: Season 2: Moondance (Episode 15)',
#        'Firefly Lane: Season 2: I Canâ\x80\x99t Go On, Iâ\x80\x99ll Go On (Episode 14)',
#        "Firefly Lane: Season 2: Can't Fight This Feeling (Episode 13)",
#        'Firefly Lane: Season 2: Time After Time (Episode 12)',
#        'Firefly Lane: Season 2: The Breast Is Yet to Come (Episode 11)',
#        'Firefly Lane: Season 2: All the Worldâ\x80\x99s a Stage (Episode 10)',
#        'Firefly Lane: Season 2: Hart Shaped Box (Episode 9)',
#        'Firefly Lane: Season 2: All Apologies (Episode 8)',
# ...

# %%
netflix_nicola['Duration'] = pd.to_timedelta(netflix_nicola['Duration'])

# %%
netflix_nicola['Duration'].sum()
# Out:
# Timedelta('1 days 18:19:00')

# %%
netflix_data
# Out:
#                        Start Time  Duration Attributes  \
# Profile Name
# Coco          2023-07-21 15:20:02  00:00:46        NaN
# Coco          2023-07-16 16:41:15  01:06:52        NaN
# Coco          2023-07-16 16:40:01  00:01:02        NaN
# Coco          2023-07-16 16:37:06  00:01:17        NaN
# Coco          2023-07-16 16:36:49  00:00:06        NaN
# ...                           ...       ...        ...
# Ð¤Ð¹Ð¶        2017-08-10 16:55:25  00:20:48        NaN
# Ð¤Ð¹Ð¶        2017-08-10 16:53:01  00:00:02        NaN
# Ð¤Ð¹Ð¶        2017-08-10 15:21:21  01:24:13        NaN
# Ð¤Ð¹Ð¶        2017-07-31 12:13:37  00:21:25        NaN
# Ð¤Ð¹Ð¶        2017-07-31 12:10:36  00:01:40        NaN
#
#                                                           Title  \
# Profile Name
# Coco          See You in My 19th Life: Season 1: Happiness, ...
# Coco                                          20th Century Girl
# Coco                                          20th Century Girl
# ...

# %%
netflix_coco = netflix_data.drop(['Ð¤Ð¹Ð¶',
                                'Nicola',
                                'Emily',
                                'Marcus'])

# %%
netflix_coco['Duration'] = pd.to_timedelta(netflix_coco['Duration'])
netflix_coco['Duration'].sum()
# Out:
# Timedelta('0 days 09:37:55')
