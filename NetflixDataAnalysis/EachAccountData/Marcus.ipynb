# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
netflix_data = pd.read_csv('datasets/netflix-report/CONTENT_INTERACTION/ViewingActivity.csv', encoding='ISO-8859-1', index_col=0)

# %%
netflix_marcus = netflix_data.drop(['Coco',
                                  'Emily',
                                  'Ð¤Ð¹Ð¶',
                                  'Nicola',])
netflix_marcus
# Out:
#                        Start Time  Duration                       Attributes  \
# Profile Name
# Marcus        2023-08-26 20:32:11  01:15:35                              NaN
# Marcus        2023-08-26 18:21:29  00:00:07  Autoplayed: user action: None;
# Marcus        2023-08-26 17:52:42  00:28:45                              NaN
# Marcus        2023-08-26 17:23:50  00:28:50                              NaN
# Marcus        2023-08-25 21:01:42  00:28:33                              NaN
# ...                           ...       ...                              ...
# Marcus        2015-12-29 22:27:23  00:01:44                              NaN
# Marcus        2015-12-29 22:18:04  00:04:44                              NaN
# Marcus        2015-12-29 22:17:00  00:00:04                              NaN
# Marcus        2015-12-29 20:11:43  01:51:07                              NaN
# Marcus        2015-12-29 19:46:20  00:23:20                              NaN
#
# ...

# %%
netflix_marcus = netflix_marcus.drop(['Attributes',
                                  'Supplemental Video Type',
                                  'Bookmark',
                                  'Latest Bookmark'], axis=1)

# %%
netflix_marcus
# Out:
#                        Start Time  Duration  \
# Profile Name
# Marcus        2023-08-26 20:32:11  01:15:35
# Marcus        2023-08-26 18:21:29  00:00:07
# Marcus        2023-08-26 17:52:42  00:28:45
# Marcus        2023-08-26 17:23:50  00:28:50
# Marcus        2023-08-25 21:01:42  00:28:33
# ...                           ...       ...
# Marcus        2015-12-29 22:27:23  00:01:44
# Marcus        2015-12-29 22:18:04  00:04:44
# Marcus        2015-12-29 22:17:00  00:00:04
# Marcus        2015-12-29 20:11:43  01:51:07
# Marcus        2015-12-29 19:46:20  00:23:20
#
#                                                           Title  \
# Profile Name
# Marcus                                                    10x10
# Marcus        Outnumbered: Series 4: The Cold Caller (Episod...
# Marcus        Outnumbered: Series 4: The Parents' Evening (E...
# Marcus          Outnumbered: Series 4: The Labrador (Episode 3)
# Marcus        Outnumbered: Series 4: The Girl's Day Out (Epi...
# ...

# %%
netflix_marcus['Title'].unique()
# Out:
# array(['10x10', 'Outnumbered: Series 4: The Cold Caller (Episode 5)',
#        "Outnumbered: Series 4: The Parents' Evening (Episode 4)", ...,
#        'The Bridge: Season 1: Episode 1',
#        '24: Season 8: 3:00 P.M. - 4:00 P.M. (Episode 24)',
#        '24: Season 1: Pilot (Episode 1)'], dtype=object)

# %%
netflix_marcus
# Out:
#                        Start Time  Duration  \
# Profile Name
# Marcus        2023-08-26 20:32:11  01:15:35
# Marcus        2023-08-26 18:21:29  00:00:07
# Marcus        2023-08-26 17:52:42  00:28:45
# Marcus        2023-08-26 17:23:50  00:28:50
# Marcus        2023-08-25 21:01:42  00:28:33
# ...                           ...       ...
# Marcus        2015-12-29 22:27:23  00:01:44
# Marcus        2015-12-29 22:18:04  00:04:44
# Marcus        2015-12-29 22:17:00  00:00:04
# Marcus        2015-12-29 20:11:43  01:51:07
# Marcus        2015-12-29 19:46:20  00:23:20
#
#                                                           Title  \
# Profile Name
# Marcus                                                    10x10
# Marcus        Outnumbered: Series 4: The Cold Caller (Episod...
# Marcus        Outnumbered: Series 4: The Parents' Evening (E...
# Marcus          Outnumbered: Series 4: The Labrador (Episode 3)
# Marcus        Outnumbered: Series 4: The Girl's Day Out (Epi...
# ...

# %%
plt.figure(figsize=(12,8))

netflix_marcus['Title'].value_counts().plot(kind='bar')

plt.title("Daddy's Rewatched shows", fontsize=15)

plt.xlabel('Title')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
# C:\Users\panda\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128 (\x80) missing from current font.
#   func(*args, **kwargs)
# C:\Users\panda\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 153 (\x99) missing from current font.
#   func(*args, **kwargs)
# C:\Users\panda\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 156 (\x9c) missing from current font.
#   func(*args, **kwargs)
# C:\Users\panda\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 157 (\x9d) missing from current font.
#   func(*args, **kwargs)
# C:\Users\panda\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 147 (\x93) missing from current font.
#   func(*args, **kwargs)
# C:\Users\panda\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 130 (\x82) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
netflix_marcus['Duration'] = pd.to_timedelta(netflix_marcus['Duration'])

# %%
netflix_marcus['Duration'].sum()
# Out:
# Timedelta('93 days 10:53:41')
