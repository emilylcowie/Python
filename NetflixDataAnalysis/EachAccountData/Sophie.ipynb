# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
netflix_data = pd.read_csv('datasets/netflix-report/CONTENT_INTERACTION/ViewingActivity.csv', encoding='ISO-8859-1', index_col=0)

# %%
netflix_sophie = netflix_data.drop(['Marcus',
                                  'Emily',
                                  'Coco',
                                  'Nicola',])
netflix_sophie
# Out:
#                        Start Time  Duration  \
# Profile Name
# Ð¤Ð¹Ð¶        2023-08-26 15:14:59  00:03:37
# Ð¤Ð¹Ð¶        2023-08-26 14:54:34  00:19:03
# Ð¤Ð¹Ð¶        2023-08-26 14:53:25  00:00:07
# Ð¤Ð¹Ð¶        2023-08-26 14:53:00  00:00:20
# Ð¤Ð¹Ð¶        2023-08-26 14:51:25  00:01:10
# ...                           ...       ...
# Ð¤Ð¹Ð¶        2017-08-10 16:55:25  00:20:48
# Ð¤Ð¹Ð¶        2017-08-10 16:53:01  00:00:02
# Ð¤Ð¹Ð¶        2017-08-10 15:21:21  01:24:13
# Ð¤Ð¹Ð¶        2017-07-31 12:13:37  00:21:25
# Ð¤Ð¹Ð¶        2017-07-31 12:10:36  00:01:40
#
#                                                Attributes  \
# Profile Name
# Ð¤Ð¹Ð¶                                                NaN
# Ð¤Ð¹Ð¶        Autoplayed: user action: User_Interaction;
# Ð¤Ð¹Ð¶                    Autoplayed: user action: None;
# Ð¤Ð¹Ð¶                    Autoplayed: user action: None;
# Ð¤Ð¹Ð¶                    Autoplayed: user action: None;
# ...

# %%
netflix_sophie = netflix_sophie.drop(['Attributes',
                                  'Supplemental Video Type',
                                  'Bookmark',
                                  'Latest Bookmark'], axis=1)

# %%
netflix_sophie
# Out:
#                        Start Time  Duration  \
# Profile Name
# Ð¤Ð¹Ð¶        2023-08-26 15:14:59  00:03:37
# Ð¤Ð¹Ð¶        2023-08-26 14:54:34  00:19:03
# Ð¤Ð¹Ð¶        2023-08-26 14:53:25  00:00:07
# Ð¤Ð¹Ð¶        2023-08-26 14:53:00  00:00:20
# Ð¤Ð¹Ð¶        2023-08-26 14:51:25  00:01:10
# ...                           ...       ...
# Ð¤Ð¹Ð¶        2017-08-10 16:55:25  00:20:48
# Ð¤Ð¹Ð¶        2017-08-10 16:53:01  00:00:02
# Ð¤Ð¹Ð¶        2017-08-10 15:21:21  01:24:13
# Ð¤Ð¹Ð¶        2017-07-31 12:13:37  00:21:25
# Ð¤Ð¹Ð¶        2017-07-31 12:10:36  00:01:40
#
#                                                           Title  \
# Profile Name
# Ð¤Ð¹Ð¶        The Dragon Prince: Season 4: Through the Looki...
# Ð¤Ð¹Ð¶                                             White Chicks
# Ð¤Ð¹Ð¶                   God Troubles Me: Season 1_hook_01_16x9
# Ð¤Ð¹Ð¶        The Prince of Tennis ~ Match! Tennis Juniors~:...
# Ð¤Ð¹Ð¶                       Hidden Love: Season 1_hook_05_16x9
# ...

# %%
netflix_sophie['Title'].unique()
# Out:
# array(['The Dragon Prince: Season 4: Through the Looking Glass (Episode 4)',
#        'White Chicks', 'God Troubles Me: Season 1_hook_01_16x9', ...,
#        'Zig & Sharko: Season 1: The Slick/ Treasure Island Tricks/ Cold Snap (Episode 2)',
#        "Zig & Sharko: Season 1: Fishy Story / Desert Island Drought / King Neptune's Court (Episode 1)",
#        'Minions'], dtype=object)

# %%
netflix_sophie['Start Time']
# Out:
# Profile Name
# Ð¤Ð¹Ð¶    2023-08-26 15:14:59
# Ð¤Ð¹Ð¶    2023-08-26 14:54:34
# Ð¤Ð¹Ð¶    2023-08-26 14:53:25
# Ð¤Ð¹Ð¶    2023-08-26 14:53:00
# Ð¤Ð¹Ð¶    2023-08-26 14:51:25
#                  ...
# Ð¤Ð¹Ð¶    2017-08-10 16:55:25
# Ð¤Ð¹Ð¶    2017-08-10 16:53:01
# Ð¤Ð¹Ð¶    2017-08-10 15:21:21
# Ð¤Ð¹Ð¶    2017-07-31 12:13:37
# Ð¤Ð¹Ð¶    2017-07-31 12:10:36
# Name: Start Time, Length: 6595, dtype: object
